# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd 
data1 = pd.read_csv('16-17 School_Quality_Report_Results_for_Early_Childhood.csv')

data2 = pd.read_csv('2018_School_Quality_Report_Results_for_PreK.csv')

data2 = data2[1:]

data2['Program Type'].value_counts()

data2.head()

data1.shape, data1.columns

# %%
data1

data2.shape, data2.columns

data1.shape,data2.shape

data1.head()

data1['Quality Review - How interesting and challenging is the curriculum?'].value_counts()

data1.shape,data1.columns

data1.head()

data1['School Type'].value_counts()

data1['Rigorous Instruction Rating'].value_counts()

data1 = data1.fillna(method='ffill')

data1['Quality Review - How effective is the teaching and learning?'].value_counts()

kdata = pd.read_csv('1.csv')

d3 = kdata.loc[kdata['School Type'] == 3]
d3.to_csv('k3.csv')

d2 = kdata.loc[kdata['School Type'] == 2]
d2.to_csv('k2.csv')

data3 = data2.drop(['Site ID','Program Name','Address 1','Address 2','Daily Start Time'],axis=1)

data3 = data3.drop(['Meals','Playspace','Dual Language'],axis=1)

data3.columns

data3 = data3.drop(['Length of Pre-K Day','Quality Review - Date of Review'],axis=1)

data3 = data3.drop(['ECERS Most Recent Assessment Year'],axis=1)

data3 = data3.drop(['CLASS Most Recent Assessment Year'],axis=1)

data3.shape, data3.columns

data3.loc[data3['Program Type'] == 'Pre-K Center']

data3.to_csv('data3.csv')

data3.head()

data3.dropna()

data3['Program Type'].value_counts()

district = data3.loc[data3['Program Type'] == 'District School']

final_df = data3.fillna(method='ffill')


final_df.to_csv('final.csv')

final_df = data1.fillna(method='ffill')


final_df = final_df.drop(['Program Code'], axis=1)

final_df['Program Type'].loc[final_df['Program Type'] == 'NYCEEC'] = 1 
final_df['Program Type'].loc[final_df['Program Type'] == 'District School'] = 2
final_df['Program Type'].loc[final_df['Program Type'] == 'Pre-K Center'] = 3
final_df['Program Type'].loc[final_df['Program Type'] == 'Charter School '] = 4

final_df['Early Drop-Off Available'].loc[final_df['Early Drop-Off Available'] == 'No'] = 0 
final_df['Early Drop-Off Available'].loc[final_df['Early Drop-Off Available'] == 'Yes'] = 1

final_df['Late Pick-Up Available'].loc[final_df['Late Pick-Up Available'] == 'No'] = 0 
final_df['Late Pick-Up Available'].loc[final_df['Late Pick-Up Available'] == 'Yes'] = 1

final_df['Trust - Survey Percent Positive'][1] 

final_df['Late Pick-Up Available'].loc[final_df['Late Pick-Up Available'] == 'No'] = 0 
final_df['Late Pick-Up Available'].loc[final_df['Late Pick-Up Available'] == 'Yes'] = 1

final_df.to_csv('final.csv')

p = pd.read_csv('final.csv')

p['Trust - Survey Percent Positive'].loc[p['Late Pick-Up Available'] == 1] = 'Perfect' 
#final_df['Trust - Survey Percent Positive'].loc[final_df['Late Pick-Up Available'] == 'Yes'] = 1

p['Trust - Survey Percent Positive'].loc[(p['Late Pick-Up Available'] >= 0.96) & ((p['Late Pick-Up Available'] <= 0.99))] = 'Good' 

p['Trust - Survey Percent Positive'].loc[p['Late Pick-Up Available'] <= 0.95] = 'Need Impovement' 

p.to_csv('p.csv')

p = p.drop(['Unnamed: 0'],axis=1)

p.to_csv('p.csv')

p

p.isna()

p.dropna()

data3

final_df = pd.read_csv('final.csv')

final_df['Program Type'].value_counts()

final_df['Program Type'].loc[final_df['Program Type'] == 'Charter School'] = 4

final_df.to_csv('final.csv')

final_df['Trust - Survey Percent Positive'].loc[final_df['']]

final_df['Trust - Survey Percent Positive'].loc[final_df['Trust - Survey Percent Positive']<= float(0.95)] = 'Need Improvement'



n = pd.read_csv('p.csv')

q = pd.read_csv('l.csv')

q.loc[q['Trust - Survey Percent Positive'] == 1, 'Label'] = 'Perfect'

q.loc[q['Trust - Survey Percent Positive'] <= 0.95, 'Label'] = 'Need Improvement'

q.loc[(q['Trust - Survey Percent Positive'] <= 0.99) &(q['Trust - Survey Percent Positive'] >= 0.96), 'Label'] = 'Good'

q = q.drop(['Trust - Survey Percent Positive'],axis=1)

q.to_csv('q.csv')
# Out:
#        DBN                                        School Name School Type  \
# 0   02M281                                   The River School         K-3
# 1   02M340                     Sixth Avenue Elementary School         K-2
# 2   03M185  P.S. 185 - The Early Childhood Discovery and D...         K-2
# 3   04M112                        P.S. 112 Jose Celso Barbosa         K-2
# 4   06M103                      Dos Puentes Elementary School         K-3
# ..     ...                                                ...         ...
# 62  84X484        Bronx Charter School for Better Learning II         K-2
# 63  84X486                       Rosalyn Yalow Charter School         K-2
# 64  84X489           South Bronx Classical Charter School III         K-2
# 65  84X497                  Storefront Academy Charter School         K-2
# 66  84X579             Bronx Charter School for Excellence II         K-2
#
#     Enrollment Rigorous Instruction Rating Collaborative Teachers Rating  \
# ...
